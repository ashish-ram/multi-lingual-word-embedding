# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'term', 'originated', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.292521
# Nearest to the: pollen, waking, brodsky, satisfying, breathe, breathtaking, pentecost, coffin,
# Nearest to at: reportage, bookstores, ltcm, whipping, rapprochement, donates, retaken, singaporean,
# Nearest to years: maternal, forest, statues, paste, kurtz, conceptions, exploitable, secessionist,
# Nearest to an: without, chattanooga, expectancies, dupuis, traitors, dorothea, jamaica, brant,
# Nearest to some: holding, gateways, inquisition, handedness, timely, mouthpieces, housewife, rosenbaum,
# Nearest to seven: styria, stags, bushnell, frederik, pomp, lilith, federal, mcveigh,
# Nearest to people: frenchmen, fachhochschule, biennial, nationality, standardisation, tryptophan, colonnade, warmest,
# Nearest to system: vox, indignation, easter, sei, gurps, chs, stores, insignia,
# Nearest to between: hydrocarbon, department, tgs, reith, hutterites, meo, millimeter, northernmost,
# Nearest to other: computability, quintet, grammars, genomics, mortgages, durban, baptiste, relativism,
# Nearest to are: tir, herse, judged, catalina, nist, cordell, special, discriminate,
# Nearest to while: efforts, mary, embroidery, junius, ons, crisp, peshawar, nigsberg,
# Nearest to and: wal, aegean, gymnasts, exemplified, mmm, marijuana, parlour, toulon,
# Nearest to a: cacao, parsed, limnic, foundational, yr, interventionism, advocating, setback,
# Nearest to known: inverse, prominently, currently, specifications, sie, walrus, dispersing, country,
# Nearest to it: roots, stanford, birds, motivation, sympathetic, manifest, northeasterly, fail,
# Average loss at step 2000: 4.369014
# Average loss at step 4000: 3.863298
# Average loss at step 6000: 3.788502
# Average loss at step 8000: 3.682303
# Average loss at step 10000: 3.620443
# Nearest to the: its, a, this, his, each, their, unclassified, an,
# Nearest to at: on, in, from, of, singaporean, first, yerushalayim, forerunner,
# Nearest to years: maternal, chess, forest, eisenman, statues, exploitable, mori, secessionist,
# Nearest to an: uneconomic, decimus, penalized, designer, europeans, the, cycling, vengeful,
# Nearest to some: many, these, gev, goblin, lake, biconditional, most, dialog,
# Nearest to seven: six, eight, three, four, nine, five, zero, two,
# Nearest to people: frenchmen, standardisation, prefixed, habitation, nationality, kosovo, watford, types,
# Nearest to system: acting, blaylock, damage, indignation, gurps, cao, vox, apprentices,
# Nearest to between: with, hutterites, by, department, during, syllogisms, desks, minsky,
# Nearest to other: clos, chemical, several, curtis, cholera, atherton, ebert, economic,
# Nearest to are: were, is, include, have, was, pandemic, must, maghreb,
# Nearest to while: but, mary, vp, triples, caveats, dordrecht, eris, southern,
# Nearest to and: or, ambience, but, who, inaccessible, s, spamming, barkley,
# Nearest to a: the, arguments, this, bunkers, anthropology, decentralization, banned, humor,
# Nearest to known: currently, such, transcends, boa, lafcadio, used, sie, well,
# Nearest to it: he, this, there, not, also, which, they, we,
# Average loss at step 12000: 3.607069
# Average loss at step 14000: 3.575374
# Average loss at step 16000: 3.412412
# Average loss at step 18000: 3.458228
# Average loss at step 20000: 3.532127
# Nearest to the: its, their, an, dividend, this, his, any, reminiscences,
# Nearest to at: in, on, with, around, after, biochemical, from, and,
# Nearest to years: time, year, chess, notoriously, speech, founders, border, eisenman,
# Nearest to an: the, penalized, uneconomic, europeans, decimus, bradley, labor, this,
# Nearest to some: many, these, several, most, other, any, shoreline, all,
# Nearest to seven: eight, six, five, nine, four, three, two, zero,
# Nearest to people: frenchmen, standardisation, habitation, assassinated, types, person, prefixed, cva,
# Nearest to system: damage, housekeeping, acting, blaylock, gurps, langford, vox, lakoff,
# Nearest to between: with, hutterites, from, department, smokey, reith, by, fulbright,
# Nearest to other: several, clos, many, some, chemical, allied, various, these,
# Nearest to are: were, is, have, was, while, include, unwillingness, but,
# Nearest to while: but, were, are, during, caveats, mary, vp, triples,
# Nearest to and: or, but, which, in, unwanted, like, circumference, who,
# Nearest to a: parsed, any, apolitical, interventionism, this, warmer, no, the,
# Nearest to known: such, used, currently, well, boa, described, transcends, terminus,
# Nearest to it: he, there, this, which, they, she, not, also,
# Average loss at step 22000: 3.504060
# Average loss at step 24000: 3.491118
# Average loss at step 26000: 3.482023
# Average loss at step 28000: 3.481794
# Average loss at step 30000: 3.501614
# Nearest to the: its, their, his, some, a, champs, this, our,
# Nearest to at: in, on, after, during, around, rigid, cyclase, biochemical,
# Nearest to years: year, hours, time, times, speech, founders, macrostate, border,
# Nearest to an: penalized, uneconomic, appealing, europeans, decimus, joyce, this, expectancies,
# Nearest to some: many, these, several, most, the, those, other, their,
# Nearest to seven: eight, six, nine, five, four, three, one, zero,
# Nearest to people: cva, types, habitation, frenchmen, person, nationality, bachelors, standardisation,
# Nearest to system: damage, housekeeping, glossary, blaylock, langford, disruption, origen, lakoff,
# Nearest to between: with, hutterites, smokey, reith, knowing, from, archaically, partners,
# Nearest to other: several, some, different, various, these, including, chemical, adverbial,
# Nearest to are: were, have, these, is, include, be, unwillingness, while,
# Nearest to while: but, were, although, would, could, mary, during, triples,
# Nearest to and: or, cotswolds, nexgen, wal, but, who, airports, overcoming,
# Nearest to a: any, the, no, very, humor, valdivia, anthropology, exchanges,
# Nearest to known: used, such, well, described, currently, regarded, defined, boa,
# Nearest to it: he, this, she, there, they, which, never, also,
# Average loss at step 32000: 3.503162
# Average loss at step 34000: 3.491325
# Average loss at step 36000: 3.457058
# Average loss at step 38000: 3.306932
# Average loss at step 40000: 3.429387
# Nearest to the: their, a, this, his, its, another, any, some,
# Nearest to at: on, rigid, during, in, mattel, near, genomic, selfish,
# Nearest to years: year, time, months, times, hours, offal, greve, eng,
# Nearest to an: uneconomic, penalized, europeans, appealing, decimus, joyce, access, maecenas,
# Nearest to some: many, these, several, any, both, their, those, most,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to people: types, cva, nationality, habitation, languages, individuals, person, men,
# Nearest to system: systems, housekeeping, langford, glossary, screename, blaylock, gurps, models,
# Nearest to between: with, hutterites, during, over, from, smokey, partners, extra,
# Nearest to other: different, several, various, adverbial, including, multiple, some, moray,
# Nearest to are: were, have, is, while, include, these, be, unwillingness,
# Nearest to while: although, when, are, were, but, though, triples, could,
# Nearest to and: or, like, but, in, ski, s, including, while,
# Nearest to a: the, another, any, kessler, nite, polytechnical, counterexamples, interventionism,
# Nearest to known: used, such, well, defined, regarded, described, boa, considered,
# Nearest to it: he, she, there, this, they, actually, which, not,
# Average loss at step 42000: 3.434447
# Average loss at step 44000: 3.454501
# Average loss at step 46000: 3.454453
# Average loss at step 48000: 3.353505
# Average loss at step 50000: 3.382144
# Nearest to the: its, this, their, his, a, ultrasonic, unclassified, some,
# Nearest to at: during, in, near, dodecanese, affluence, wed, subsurface, on,
# Nearest to years: year, months, times, days, hours, notoriously, greve, privateer,
# Nearest to an: uneconomic, appealing, penalized, thunderbird, europeans, access, mckay, soured,
# Nearest to some: many, these, several, both, most, any, various, those,
# Nearest to seven: eight, nine, six, four, five, three, zero, one,
# Nearest to people: men, nationality, person, children, cva, persons, individuals, habitation,
# Nearest to system: systems, housekeeping, origen, sprinkling, models, disassembly, cordial, kristina,
# Nearest to between: with, hutterites, over, smokey, partners, regatta, debugging, during,
# Nearest to other: different, various, some, many, these, several, multiple, involving,
# Nearest to are: were, is, include, have, these, those, harlequin, be,
# Nearest to while: although, when, but, though, however, during, and, where,
# Nearest to and: or, while, including, disobedience, but, of, davies, declares,
# Nearest to a: interventionism, another, any, the, bunkers, apolitical, incunabula, humorously,
# Nearest to known: used, such, well, regarded, described, recognized, defined, available,
# Nearest to it: he, she, there, this, they, still, often, probably,
# Average loss at step 52000: 3.437393
# Average loss at step 54000: 3.427283
# Average loss at step 56000: 3.439086
# Average loss at step 58000: 3.397511
# Average loss at step 60000: 3.391574
# Nearest to the: its, their, a, his, this, some, these, shouted,
# Nearest to at: in, during, biochemical, near, rigid, genomic, after, movie,
# Nearest to years: year, days, months, times, hours, decades, weeks, notoriously,
# Nearest to an: uneconomic, appealing, designer, penalized, tapping, europeans, dorothea, exerted,
# Nearest to some: many, several, these, most, any, various, this, those,
# Nearest to seven: eight, six, four, nine, five, three, zero, one,
# Nearest to people: men, children, persons, types, blends, nationality, individuals, person,
# Nearest to system: systems, housekeeping, models, kristina, glossary, cordial, disassembly, screename,
# Nearest to between: with, hutterites, over, partners, among, smokey, within, in,
# Nearest to other: various, different, multiple, several, more, goro, many, adverbial,
# Nearest to are: were, is, have, include, lafcadio, these, be, those,
# Nearest to while: although, when, though, but, after, before, during, were,
# Nearest to and: or, but, including, than, although, mmm, chelsea, in,
# Nearest to a: the, another, interventionism, any, bunkers, etch, provocative, every,
# Nearest to known: used, such, regarded, well, recognized, described, defined, considered,
# Nearest to it: he, there, she, this, which, still, they, we,
# Average loss at step 62000: 3.240203
# Average loss at step 64000: 3.255310
# Average loss at step 66000: 3.405472
# Average loss at step 68000: 3.395443
# Average loss at step 70000: 3.359131
# Nearest to the: their, its, a, this, any, these, each, our,
# Nearest to at: during, near, in, after, genomic, biochemical, spock, usn,
# Nearest to years: days, months, times, year, decades, hours, weeks, greve,
# Nearest to an: uneconomic, appealing, penalized, dorothea, seniority, europeans, likened, the,
# Nearest to some: many, several, these, various, most, all, both, their,
# Nearest to seven: six, eight, four, nine, five, three, two, zero,
# Nearest to people: men, children, women, individuals, persons, types, writers, students,
# Nearest to system: systems, housekeeping, models, design, disassembly, ashton, lanzarote, glossary,
# Nearest to between: with, among, hutterites, within, partners, smokey, from, in,
# Nearest to other: various, different, multiple, smaller, some, many, several, goro,
# Nearest to are: were, include, have, these, is, although, including, while,
# Nearest to while: although, though, when, however, but, where, before, including,
# Nearest to and: or, which, but, like, while, including, shandy, alike,
# Nearest to a: the, another, interventionism, counterexamples, bunkers, nite, this, demilitarized,
# Nearest to known: used, such, regarded, described, well, defined, recognized, seen,
# Nearest to it: he, she, there, this, they, still, we, then,
# Average loss at step 72000: 3.375321
# Average loss at step 74000: 3.350981
# Average loss at step 76000: 3.312496
# Average loss at step 78000: 3.353394
# Average loss at step 80000: 3.382688
# Nearest to the: its, this, a, their, his, each, dividend, catalana,
# Nearest to at: in, during, before, on, rigid, around, near, after,
# Nearest to years: days, months, times, year, hours, decades, weeks, centuries,
# Nearest to an: uneconomic, europeans, penalized, tapping, appealing, thunderbird, dorothea, designer,
# Nearest to some: many, several, these, various, most, this, any, both,
# Nearest to seven: six, eight, five, four, three, nine, zero, two,
# Nearest to people: children, men, women, persons, individuals, writers, citizens, jews,
# Nearest to system: systems, design, models, lanzarote, colby, housekeeping, kristina, disassembly,
# Nearest to between: among, with, within, hutterites, in, over, smokey, through,
# Nearest to other: various, different, many, goro, adverbial, some, smaller, multiple,
# Nearest to are: were, include, although, is, have, these, those, be,
# Nearest to while: although, though, however, when, after, before, but, and,
# Nearest to and: or, but, while, including, myrtle, mendoza, although, than,
# Nearest to a: apolitical, another, the, cocteau, bunkers, bernese, interventionism, every,
# Nearest to known: used, regarded, described, defined, recognized, seen, such, available,
# Nearest to it: he, she, there, this, they, never, still, not,
# Average loss at step 82000: 3.404824
# Average loss at step 84000: 3.412516
# Average loss at step 86000: 3.388758
# Average loss at step 88000: 3.355707
# Average loss at step 90000: 3.373247
# Nearest to the: its, their, this, a, his, unclassified, any, mumford,
# Nearest to at: during, near, after, in, before, on, while, squirt,
# Nearest to years: days, months, hours, year, decades, times, weeks, centuries,
# Nearest to an: uneconomic, appealing, dorothea, penalized, imitation, thunderbird, europeans, gothic,
# Nearest to some: many, several, these, most, any, this, various, those,
# Nearest to seven: eight, four, five, six, nine, three, zero, one,
# Nearest to people: children, men, women, persons, ripened, writers, citizens, peoples,
# Nearest to system: systems, models, process, disassembly, brooklyn, terminology, function, portugal,
# Nearest to between: within, among, with, hutterites, from, through, scalars, across,
# Nearest to other: various, food, multiple, goro, different, fringe, smells, smaller,
# Nearest to are: were, include, is, these, have, although, remain, those,
# Nearest to while: although, though, when, before, after, but, were, during,
# Nearest to and: or, but, looksmart, including, while, in, textiles, of,
# Nearest to a: the, interventionism, apolitical, another, every, nite, campaigner, coo,
# Nearest to known: used, regarded, described, such, available, seen, referred, defined,
# Nearest to it: he, she, this, there, they, itself, still, often,
# Average loss at step 92000: 3.400242
# Average loss at step 94000: 3.252154
# Average loss at step 96000: 3.360015
# Average loss at step 98000: 3.248334
# Average loss at step 100000: 3.361128
# Nearest to the: their, his, its, your, a, each, our, any,
# Nearest to at: during, after, in, rigid, on, near, deserters, speedy,
# Nearest to years: days, months, hours, year, decades, times, weeks, centuries,
# Nearest to an: uneconomic, penalized, europeans, dorothea, songwriters, expectancies, another, seniority,
# Nearest to some: many, several, these, any, various, most, numerous, all,
# Nearest to seven: eight, four, nine, six, five, three, two, zero,
# Nearest to people: children, women, men, citizens, persons, students, ripened, jews,
# Nearest to system: systems, function, disassembly, housekeeping, lanzarote, terminology, program, ashton,
# Nearest to between: among, with, within, through, hutterites, over, in, scalars,
# Nearest to other: various, goro, others, smaller, food, different, adverbial, older,
# Nearest to are: were, include, have, is, these, while, remain, although,
# Nearest to while: although, when, though, before, after, but, where, are,
# Nearest to and: or, but, although, however, including, while, of, who,
# Nearest to a: the, any, another, apolitical, trasimene, trisha, interventionism, cowan,
# Nearest to known: used, regarded, such, described, available, recognized, defined, seen,
# Nearest to it: he, she, this, there, they, probably, itself, which,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
